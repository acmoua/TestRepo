# %%
import urllib.request 
from bs4 import BeautifulSoup as soup

# %%
myUrl = 'https://www.glassdoor.com/job-listing/software-engineer-no-prior-coding-experience-required-revature-JV_IC1146927_KO0,53_KE54,62.htm?jl=3375800965&ctt=1582607836248'
myUrl
# Out:
# 'https://www.glassdoor.com/job-listing/software-engineer-no-prior-coding-experience-required-revature-JV_IC1146927_KO0,53_KE54,62.htm?jl=3375800965&ctt=1582607836248'

# %%
page=urllib.request.Request(myUrl,headers={'User-Agent': 'Mozilla/5.0'}) 
infile=urllib.request.urlopen(page).read()
data = infile.decode('ISO-8859-1') # Read the content as string decoded with ISO-8859-1

print(data) # Print the data to the screen
# Out:
# <!DOCTYPE html>
# <html lang='en' xmlns:fb='http://www.facebook.com/2008/fbml' xmlns:og='http://opengraph.org/schema/' class='flex'>
#
# ...
